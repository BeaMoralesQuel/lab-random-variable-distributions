# %% [markdown]
# # Lab | Random variable distributions

# %% [markdown]
# ## 1. Use the numerical variables from our dataset this week.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numerical=pd.read_csv('numerical.csv')
numerical
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# ## 2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
for col in numerical.columns:
    sns.displot(numerical[col],kde=True)
    plt.show()

# %% [markdown]
# ### Looking at the graphs we cannot say that the variables follow a normal distribution.
# ### Moreover, some variables would have to be shortened to see whether or not they follow a normal distribution.

# %% [markdown]
# ## 3. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
#Log Transformation

# %%
num_transform=np.where(np.isfinite(np.log10(numerical)),np.log10(numerical),0)
# Out:
# /Users/beamoralesquel/anaconda3/lib/python3.10/site-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: divide by zero encountered in log10
#   result = func(self.values, **kwargs)

# %%
num_transform=pd.DataFrame(num_transform,columns=numerical.columns)
num_transform
# Out:
#       customer_lifetime_value    income  monthly_premium_auto  \
# 0                    3.441462  4.750308              1.838849
# 1                    3.843827  0.000000              1.973128
# 2                    4.110166  4.688126              2.033424
# 3                    3.883426  0.000000              2.025306
# 4                    3.449277  4.641831              1.863323
# ...                       ...       ...                   ...
# 9129                 4.369327  4.856976              1.863323
# 9130                 3.490873  4.334534              1.897627
# 9131                 3.911897  0.000000              1.929419
# 9132                 3.876474  4.341256              1.982271
# 9133                 3.416946  0.000000              1.886491
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    1.505150                       0.698970
# 1                    1.113943                       1.623249
# ...

# %%
for col in num_transform.columns:
    sns.displot(num_transformed[col],kde=True)
    plt.show()
